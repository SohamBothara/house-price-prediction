# %% [markdown]
# <a href="https://colab.research.google.com/github/SohamBothara/python_ml_projects/blob/main/Total_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Creating a pandas dataframe

# %%
 from sklearn.datasets import fetch_california_housing
 housing = fetch_california_housing()

# %%
type(housing)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(housing)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
#pandas dataframe
housing_df = pd.DataFrame(housing.data, columns=housing.feature_names)
housing_df['target'] = housing.target

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
housing_df.shape
# Out:
# (20640, 9)

# %% [markdown]
# Importing data from a csv file to a pandas dataframe

# %%
#csv file to pandas dataframe
rock_df = pd.read_csv('/content/Copy of sonar data.csv')

# %%
rock_df.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#    0.0090  0.0032  R
# 0  0.0052  0.0044  R
# 1  0.0095  0.0078  R
# 2  0.0040  0.0117  R
# ...

# %%
type(rock_df)
# Out:
# pandas.core.frame.DataFrame

# %%
rock_df.shape
# Out:
# (207, 61)

# %% [markdown]
# Loading the data from the excel fiel to a pandad dataframe
#
# pd.read_excel('file path')

# %% [markdown]
# exporting a dataframe to a csv file

# %%
housing_df.to_csv('housing.csv')

# %% [markdown]
# exporting the pandas dataframe to an excel file
#
# df.to_excel('file name')

# %%
#creating a dataframe with random values
import numpy as np
df = pd.DataFrame(np.random.rand(5, 3), columns=['A', 'B', 'C'])

# %%
print(df)
# Out:
#           A         B         C
# 0  0.269770  0.587231  0.405224
# 1  0.567560  0.874887  0.567487
# 2  0.228115  0.056731  0.780483
# 3  0.128132  0.783628  0.545896
# 4  0.822574  0.479025  0.220777

# %%
df.shape
# Out:
# (5, 3)

# %% [markdown]
# inspecting a dataframe

# %%
# find number of rows and columns
housing_df.shape
# Out:
# (20640, 9)

# %%
#print first 5 rows
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
#last 5 rows
housing_df.tail()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  target
# 20635    -121.09   0.781
# 20636    -121.21   0.771
# 20637    -121.22   0.923
# 20638    -121.32   0.847
# 20639    -121.24   0.894

# %%
#information about the dataframe
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   target      20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
#find the number of missign values
housing_df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# target        0
# dtype: int64

# %%
rock_df.head()
rock_df.shape
# Out:
# (207, 61)

# %%
#counting the vlaues based on labels
rock_df.iloc[:, 60].value_counts()  # If '60' is the column index
# Out:
# R
# M    111
# R     96
# Name: count, dtype: int64

# %%
rock_df.groupby(rock_df.iloc[:, 60]).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %%
#count or nnumber of values

housing_df.count()
# Out:
# MedInc        20640
# HouseAge      20640
# AveRooms      20640
# AveBedrms     20640
# Population    20640
# AveOccup      20640
# Latitude      20640
# Longitude     20640
# target        20640
# dtype: int64

# %%
#mean value column wise


housing_df.mean()
# Out:
# MedInc           3.870671
# HouseAge        28.639486
# AveRooms         5.429000
# AveBedrms        1.096675
# Population    1425.476744
# AveOccup         3.070655
# Latitude        35.631861
# Longitude     -119.569704
# target           2.068558
# dtype: float64

# %%
#standard deviation
housing_df.std()
# Out:
# MedInc           1.899822
# HouseAge        12.585558
# AveRooms         2.474173
# AveBedrms        0.473911
# Population    1132.462122
# AveOccup        10.386050
# Latitude         2.135952
# Longitude        2.003532
# target           1.153956
# dtype: float64

# %%
#minimum value and max value
housing_df.min()
# Out:
# MedInc          0.499900
# HouseAge        1.000000
# AveRooms        0.846154
# AveBedrms       0.333333
# Population      3.000000
# AveOccup        0.692308
# Latitude       32.540000
# Longitude    -124.350000
# target          0.149990
# dtype: float64

# %%
housing_df.max()
# Out:
# MedInc           15.000100
# HouseAge         52.000000
# AveRooms        141.909091
# AveBedrms        34.066667
# Population    35682.000000
# AveOccup       1243.333333
# Latitude         41.950000
# Longitude      -114.310000
# target            5.000010
# dtype: float64

# %%
#all statistical measure in one go
housing_df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude        target
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
#add column to dataframe
housing_df['Price']=housing.target

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target  Price
# 0    -122.23   4.526  4.526
# 1    -122.22   3.585  3.585
# 2    -122.24   3.521  3.521
# 3    -122.25   3.413  3.413
# 4    -122.25   3.422  3.422

# %%
#removing a row
housing_df.drop(index=0, axis=0, inplace=True)
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5  4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
#
#    Longitude  target  Price
# 1    -122.22   3.585  3.585
# 2    -122.24   3.521  3.521
# 3    -122.25   3.413  3.413
# 4    -122.25   3.422  3.422
# 5    -122.25   2.697  2.697

# %%
#drop a column
housing_df.drop(columns='MedInc', axis=1, inplace=True) # by inplace true we permanently delete the column or row
housing_df.head()
# Out:
#    HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  Longitude  \
# 1      21.0  6.238137   0.971880      2401.0  2.109842     37.86    -122.22
# 2      52.0  8.288136   1.073446       496.0  2.802260     37.85    -122.24
# 3      52.0  5.817352   1.073059       558.0  2.547945     37.85    -122.25
# 4      52.0  6.281853   1.081081       565.0  2.181467     37.85    -122.25
# 5      52.0  4.761658   1.103627       413.0  2.139896     37.85    -122.25
#
#    target  Price
# 1   3.585  3.585
# 2   3.521  3.521
# 3   3.413  3.413
# 4   3.422  3.422
# 5   2.697  2.697

# %%
#locating a row using index value
housing_df.iloc[2]
# Out:
# HouseAge       52.000000
# AveRooms        5.817352
# AveBedrms       1.073059
# Population    558.000000
# AveOccup        2.547945
# Latitude       37.850000
# Longitude    -122.250000
# target          3.413000
# Price           3.413000
# Name: 3, dtype: float64

# %%
#loate a particular column
print(housing_df.iloc[:,0]) # first column of dataframe
print(housing_df.iloc[:,1]) # second column of dataframe
print(housing_df.iloc[:,2]) # third column of dataframe
print(housing_df.iloc[:,3]) # fourth column of dataframe
print(housing_df.iloc[:,4]) # fifth column of dataframe
# Out:
# 1        21.0
# 2        52.0
# 3        52.0
# 4        52.0
# 5        52.0
#          ...
# 20635    25.0
# 20636    18.0
# 20637    17.0
# 20638    18.0
# 20639    16.0
# Name: HouseAge, Length: 20639, dtype: float64
# 1        6.238137
# 2        8.288136
# 3        5.817352
# 4        6.281853
# 5        4.761658
#            ...
# 20635    5.045455
# 20636    6.114035
# 20637    5.205543
# 20638    5.329513
# 20639    5.254717
# Name: AveRooms, Length: 20639, dtype: float64
# 1        0.971880
# 2        1.073446
# 3        1.073059
# 4        1.081081
# 5        1.103627
#            ...
# 20635    1.133333
# 20636    1.315789
# 20637    1.120092
# 20638    1.171920
# 20639    1.162264
# Name: AveBedrms, Length: 20639, dtype: float64
# 1        2401.0
# 2         496.0
# 3         558.0
# 4         565.0
# 5         413.0
#           ...
# 20635     845.0
# 20636     356.0
# 20637    1007.0
# 20638     741.0
# 20639    1387.0
# Name: Population, Length: 20639, dtype: float64
# ...
